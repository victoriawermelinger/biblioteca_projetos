# %% [markdown]
# # **Fundamentos de Python - Escolha de Datasets Potenciais**
#
# Instruções
#
# Identificar 3 datasets que atendam às seguintes condições:<p>
# a) pelo menos 2000 linhas <p>
# b) pelo menos 15 colunas. <p>
#
# Você pode buscar nas seguintes fontes: Github, Kaggle, Google Dataset Search (também pode ser um arquivo próprio).
#
# Criar uma conta no GitHub e hospedar os arquivos lá.
#
# Carregar os arquivos correspondentes por meio da biblioteca Pandas.
#
# O código deve estar em um notebook e deve ter sido testado.
#
# Descrever as variáveis potencialmente interessantes em cada arquivo, levando em consideração o contexto do caso
#
#
# **Formato**
#
# Para a pré-entrega, gere um arquivo no formato .ipynb. O arquivo deve ter o nome “Datasets+Sobrenome.ipynb”.

# %% [markdown]
# ## **Impacto do tempo de tela na saúde mental**
#
# **Sobre o conjunto de dados**<p>
# 🧠 Visão geral<p>
# O conjunto de dados Hábitos Digitais vs. Saúde Mental é um conjunto de dados sintéticos criado para investigar as possíveis relações entre o estilo de vida digital da Geração Z — particularmente tempo de tela, engajamento em mídias sociais e sono — e seus indicadores de saúde mental, como níveis de estresse e pontuações de humor. Ele contém 100.000 linhas de dados em 6 variáveis-chave que simulam padrões de comportamento do mundo real.
#
# Este conjunto de dados foi desenvolvido para uso em análise exploratória de dados (EDA), análise de correlação, prática de engenharia de recursos, modelagem de aprendizado de máquina (regressão/classificação) e aplicações de conscientização em saúde pública. É especialmente útil para estudantes, cientistas de dados e pesquisadores interessados ​​na interseção entre o uso da tecnologia e a psicologia na juventude moderna.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Sobre este arquivo
# O digital_habits_vs_mental_health.csvconjunto de dados consiste em 100.000 linhas e 6 colunas , capturando insights sobre como os hábitos digitais se relacionam com os resultados de saúde mental. Cada registro representa os dados relatados por um indivíduo sobre tempo de tela, uso de mídias sociais e indicadores de bem-estar mental.
#
#
#
# Total de inscrições : 100.000<p>
# Características (Colunas) : 6<p>
# Valores ausentes : Nenhum (totalmente limpo)<p>
# Tipos de dados : Float e Integer<p>
# Foco principal : Analisar a influência do comportamento digital (tempo de tela, uso da plataforma, uso do TikTok) em fatores de saúde mental, como estresse e humor.

# %%
# prompt: import pandas
import pandas as pd

# Ler um arquivo CSV
df_habitsvsmental = pd.read_csv('/home/wermelinger_v/Documentos/GitHub/biblioteca_projetos/ CODERHOUSE - 7209 Data Science  /digital_habits_vs_mental_health.csv')

print(df_habitsvsmental.head())
# Out:
#    screen_time_hours  social_media_platforms_used  hours_on_TikTok  \
# 0               10.3                            2              5.3
# 1                6.5                            5              3.5
# 2                9.1                            4              2.8
# 3                6.5                            3              2.5
# 4                2.1                            3              1.2
#
#    sleep_hours  stress_level  mood_score
# 0          4.4            10           5
# 1          6.2             8           8
# 2          6.6             7           8
# 3          6.5             7           9
# 4          7.8             2          10

# %%
# prompt: ver se tem dados nulos

print(df_habitsvsmental.isnull().sum())
# Out:
# screen_time_hours              0
# social_media_platforms_used    0
# hours_on_TikTok                0
# sleep_hours                    0
# stress_level                   0
# mood_score                     0
# dtype: int64

# %%
# Informações sobre a tabela

df_habitsvsmental.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   screen_time_hours            100000 non-null  float64
#  1   social_media_platforms_used  100000 non-null  int64
#  2   hours_on_TikTok              100000 non-null  float64
#  3   sleep_hours                  100000 non-null  float64
#  4   stress_level                 100000 non-null  int64
#  5   mood_score                   100000 non-null  int64
# dtypes: float64(3), int64(3)
# memory usage: 4.6 MB

# %%
print(df_habitsvsmental.columns.tolist())
# Out:
# ['tempo_uso_tela_hrs', 'plataformas_redes_sociais_usadas', 'horas_no_tiktok', 'horas_sono', 'nivel_estresse', 'pontuacao_humor']

# %%
# prompt: Renomear as colunas para o portugues

df_habitsvsmental.rename(columns={
    'screen_time_hours': 'tempo_uso_tela_hrs',
    'social_media_platforms_used': 'plataformas_redes_sociais_usadas',
    'hours_on_TikTok': 'horas_no_tiktok',
    'sleep_hours': 'horas_sono',
    'stress_level': 'nivel_estresse',
    'mood_score': 'pontuacao_humor'
}, inplace=True)

print(df_habitsvsmental.head())
# Out:
#    tempo_uso_tela_hrs  plataformas_redes_sociais_usadas  horas_no_tiktok  \
# 0                10.3                                 2              5.3
# 1                 6.5                                 5              3.5
# 2                 9.1                                 4              2.8
# 3                 6.5                                 3              2.5
# 4                 2.1                                 3              1.2
#
#    horas_sono  nivel_estresse  pontuacao_humor
# 0         4.4              10                5
# 1         6.2               8                8
# 2         6.6               7                8
# 3         6.5               7                9
# 4         7.8               2               10

# %% [markdown]
# # **Prática Integradora: Visualizações em Python**
# **Consigna**<p>
#
# * Você escolherá um dos datasets da atividade anterior “Escolha de Potenciais Datasets e Importação com a biblioteca Pandas”.
#
# * Posteriormente, na mesma notebook, você realizará 3 gráficos diferentes com Matplotlib e 3 com Seaborn.
#
# * Deve-se utilizar pelo menos um parâmetro adicional (grid, hue, etc.) que enriqueça a legibilidade dos gráficos.
#
# Finalmente, cada gráfico será interpretado com o objetivo de obter insights relevantes que permitam responder à pergunta problema.

# %%
# prompt: Lógica: Mostra a distribuição da variável tempo de tela para Ajuda a entender quantas pessoas passam mais ou menos tempo no celular/computador.

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.histplot(df_habitsvsmental['tempo_uso_tela_hrs'], kde=True, bins=30)
plt.title('Distribuição do Tempo de Uso de Tela em Horas')
plt.xlabel('Tempo de Uso de Tela (horas)')
plt.ylabel('Frequência')
plt.grid(axis='y', alpha=0.75)
plt.show()

# Insights:
# O histograma mostra a distribuição do tempo de uso de tela em horas.
# A maioria das pessoas neste dataset parece ter um tempo de uso de tela entre X e Y horas (observar o pico no gráfico).
# Há uma cauda para a direita, indicando que algumas pessoas têm um tempo de uso de tela significativamente maior.

# %%
# prompt: Lógica: Agrupa os dados por quantidade de plataformas usadas e calcula a média do humor. Analisa se mais redes sociais impactam no bem-estar.

import matplotlib.pyplot as plt
# Agrupar por número de plataformas e calcular a média do humor
mood_by_platforms = df_habitsvsmental.groupby('plataformas_redes_sociais_usadas')['pontuacao_humor'].mean().reset_index()

# Exibir os resultados
print("\nMédia do humor por quantidade de plataformas de redes sociais usadas:")
print(mood_by_platforms)

# Visualização
plt.figure(figsize=(10, 6))
sns.barplot(x='plataformas_redes_sociais_usadas', y='pontuacao_humor', data=mood_by_platforms, palette='viridis')
plt.title('Média do Humor vs. Quantidade de Plataformas de Redes Sociais Usadas')
plt.xlabel('Quantidade de Plataformas de Redes Sociais Usadas')
plt.ylabel('Pontuação Média do Humor')
plt.grid(axis='y', alpha=0.75)
plt.show()

# Insights:
# Este gráfico de barras mostra a relação entre a quantidade de plataformas de redes sociais usadas e a pontuação média do humor.
# Observa-se uma tendência de [descrever a tendência observada, por exemplo: o humor médio parece diminuir/aumentar à medida que o número de plataformas aumenta, ou não há uma relação clara].
# Isso sugere que [interpretar a tendência em relação ao bem-estar, por exemplo: usar mais redes sociais pode estar associado a um humor ligeiramente pior/melhor/neutro].
# Para uma análise mais robusta, seria interessante considerar outros fatores simultaneamente, como o tempo total de uso de tela ou o nível de estresse.
# Out:
# Média do humor por quantidade de plataformas de redes sociais usadas:
#    plataformas_redes_sociais_usadas  pontuacao_humor
# 0                                 1         9.057191
# 1                                 2         9.056537
# 2                                 3         9.065656
# 3                                 4         9.069252
# 4                                 5         9.055180
# /tmp/ipykernel_9558/2402886325.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='plataformas_redes_sociais_usadas', y='pontuacao_humor', data=mood_by_platforms, palette='viridis')

# %%
# prompt: Lógica: Ordena os dados pelas horas de sono e plota a variação da pontuação de humor. Ajuda a ver se quem dorme mais se sente melhor.

import matplotlib.pyplot as plt
# Ordena os dados pelas horas de sono
df_sorted_by_sleep = df_habitsvsmental.sort_values('horas_sono')

# Plota a variação da pontuação de humor com base nas horas de sono
plt.figure(figsize=(12, 7))
sns.lineplot(x='horas_sono', y='pontuacao_humor', data=df_sorted_by_sleep, marker='o') # Adiciona marcadores para pontos de dados
plt.title('Variação da Pontuação de Humor com Base nas Horas de Sono')
plt.xlabel('Horas de Sono')
plt.ylabel('Pontuação de Humor')
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# Insights:
# Este gráfico de linha mostra como a pontuação de humor varia com a quantidade de horas de sono.
# A linha tende a [descrever a tendência, por exemplo: aumentar, diminuir, manter-se estável] à medida que as horas de sono aumentam.
# Podemos observar que [descrever um ponto específico, por exemplo: há um pico de humor em torno de X horas de sono, ou o humor parece cair drasticamente com menos de Y horas de sono].
# Isso sugere que [interpretar a relação, por exemplo: dormir mais parece estar associado a um humor melhor, ou há uma quantidade ideal de sono para o humor].
# É importante lembrar que esta é uma correlação e não implica causalidade direta; outros fatores também influenciam o humor.

# %%
# prompt: Lógica: Mostra a dispersão e mediana dos níveis de estresse conforme a quantidade de redes sociais. Detecta se mais redes aumentam o estresse.

import matplotlib.pyplot as plt
# Lógica: Mostra a dispersão e mediana dos níveis de estresse conforme a quantidade de redes sociais. Detecta se mais redes aumentam o estresse.

plt.figure(figsize=(10, 6))
sns.boxplot(x='plataformas_redes_sociais_usadas', y='nivel_estresse', data=df_habitsvsmental, palette='coolwarm')
plt.title('Nível de Estresse vs. Quantidade de Plataformas de Redes Sociais Usadas')
plt.xlabel('Quantidade de Plataformas de Redes Sociais Usadas')
plt.ylabel('Nível de Estresse')
plt.grid(axis='y', alpha=0.75)
plt.show()

# Insights:
# Este gráfico de caixa (boxplot) visualiza a distribuição do nível de estresse para cada quantidade diferente de plataformas de redes sociais utilizadas.
# Cada caixa representa o intervalo interquartil (IQR), a linha no meio da caixa é a mediana, e os "bigodes" se estendem aos dados dentro de 1.5 vezes o IQR. Pontos individuais fora dos bigodes são considerados outliers.
# Ao observar as medianas das caixas, podemos ver se há uma tendência clara no nível de estresse à medida que o número de plataformas aumenta.
# A dispersão (tamanho da caixa e extensão dos bigodes) mostra a variabilidade do nível de estresse para cada grupo. Uma caixa maior ou bigodes mais longos indicam maior variabilidade.
# Podemos observar se [descrever a tendência observada na mediana, por exemplo: a mediana do nível de estresse parece aumentar à medida que o número de plataformas aumenta, ou parece diminuir, ou não há uma tendência clara].
# A presença de outliers (pontos individuais) indica indivíduos com níveis de estresse excepcionalmente altos ou baixos para o número de plataformas que utilizam.
# Em geral, se as medianas e a dispersão tendem a ser maiores para grupos que utilizam mais plataformas, isso pode sugerir uma associação positiva entre o uso de mais redes sociais e níveis mais altos de estresse.
# Out:
# /tmp/ipykernel_9558/3326204709.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='plataformas_redes_sociais_usadas', y='nivel_estresse', data=df_habitsvsmental, palette='coolwarm')

# %%
# prompt: Lógica: Relaciona o tempo no TikTok com o humor, destacando com cores diferentes os níveis de estresse. Ajuda a ver se mais TikTok impacta negativamente.

import matplotlib.pyplot as plt
# Scatter plot para relacionar horas no TikTok com pontuação de humor, colorindo por nível de estresse
plt.figure(figsize=(12, 7))
sns.scatterplot(x='horas_no_tiktok', y='pontuacao_humor', hue='nivel_estresse', data=df_habitsvsmental, palette='viridis', alpha=0.6)
plt.title('Horas no TikTok vs. Pontuação de Humor (Colorido por Nível de Estresse)')
plt.xlabel('Horas no TikTok')
plt.ylabel('Pontuação de Humor')
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend(title='Nível de Estresse')
plt.show()

# Insights:
# Este scatter plot mostra a relação entre as horas passadas no TikTok e a pontuação de humor, com os pontos coloridos de acordo com o nível de estresse.
# Cada ponto no gráfico representa um indivíduo no dataset.
# Podemos observar se há uma tendência geral na pontuação de humor à medida que as horas no TikTok aumentam. Por exemplo, o humor tende a diminuir/aumentar/permanecer o mesmo?
# A coloração dos pontos permite visualizar como o nível de estresse se distribui nessa relação. Por exemplo, os pontos de alto estresse tendem a se agrupar em uma área específica do gráfico (por exemplo, mais horas no TikTok e menor humor)?
# Se observarmos que pontos com níveis de estresse mais altos tendem a estar associados a mais horas no TikTok e/ou menor pontuação de humor, isso pode sugerir uma correlação entre o uso do TikTok, estresse e humor.
# No entanto, é crucial lembrar que correlação não implica causalidade. Outros fatores podem estar influenciando simultaneamente todas essas variáveis.
# Este gráfico ajuda a identificar padrões visuais e áreas de interesse para uma análise mais aprofundada.

# %%
# prompt: Lógica: Calcula a correlação entre todas as variáveis numéricas. O mapa mostra quais hábitos digitais têm mais relação com sono, estresse e humor.

import matplotlib.pyplot as plt
# Seleciona apenas as colunas numéricas para o cálculo da correlação
df_numeric = df_habitsvsmental[['tempo_uso_tela_hrs', 'plataformas_redes_sociais_usadas', 'horas_no_tiktok', 'horas_sono', 'nivel_estresse', 'pontuacao_humor']]

# Calcula a matriz de correlação
correlation_matrix = df_numeric.corr()

# Exibe a matriz de correlação
print("\nMatriz de Correlação entre Variáveis Numéricas:")
print(correlation_matrix)

# Visualiza a matriz de correlação usando um mapa de calor (heatmap)
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Mapa de Calor da Matriz de Correlação')
plt.show()

# Insights:
# Este mapa de calor mostra as correlações entre todos os pares de variáveis numéricas no dataset.
# Os valores variam de -1 a 1. Valores próximos a 1 indicam uma forte correlação positiva (à medida que uma variável aumenta, a outra também tende a aumentar). Valores próximos a -1 indicam uma forte correlação negativa (à medida que uma variável aumenta, a outra tende a diminuir). Valores próximos a 0 indicam pouca ou nenhuma correlação linear.
# A diagonal principal é sempre 1, pois uma variável está perfeitamente correlacionada consigo mesma.
# Observando as células onde as linhas e colunas se cruzam (exceto a diagonal):
# - Procure por valores altos (próximos a 1 ou -1) nas células que relacionam os hábitos digitais ('tempo_uso_tela_hrs', 'plataformas_redes_sociais_usadas', 'horas_no_tiktok') com os resultados de saúde mental ('horas_sono', 'nivel_estresse', 'pontuacao_humor').
# - Por exemplo, uma correlação positiva forte entre 'tempo_uso_tela_hrs' e 'nivel_estresse' sugeriria que mais tempo de tela está associado a níveis mais altos de estresse.
# - Uma correlação negativa forte entre 'horas_no_tiktok' e 'pontuacao_humor' sugeriria que mais horas no TikTok estão associadas a pontuações de humor mais baixas.
# - As cores no mapa de calor também ajudam a visualizar a força e direção da correlação (geralmente azul/roxo para negativo, vermelho/laranja para positivo, e cores neutras para perto de zero).
# Este mapa de calor é uma ferramenta poderosa para identificar rapidamente quais variáveis têm as relações lineares mais fortes umas com as outras. No entanto, é importante lembrar que correlação não implica causalidade, e esta análise é apenas um ponto de partida para entender as relações entre as variáveis.
# Out:
# Matriz de Correlação entre Variáveis Numéricas:
#                                   tempo_uso_tela_hrs  \
# tempo_uso_tela_hrs                          1.000000
# plataformas_redes_sociais_usadas            0.003862
# horas_no_tiktok                             0.736715
# horas_sono                                  0.000469
# nivel_estresse                              0.494091
# pontuacao_humor                            -0.342558
#
#                                   plataformas_redes_sociais_usadas  \
# tempo_uso_tela_hrs                                        0.003862
# plataformas_redes_sociais_usadas                          1.000000
# horas_no_tiktok                                           0.003941
# horas_sono                                                0.000658
# nivel_estresse                                            0.004197
# pontuacao_humor                                           0.000958
#
# ...

# %%
# Salvar o dataframe em um arquivo CSV
df_habitsvsmental.to_csv('habitos_digitais_vs_saude_mental_salvo.csv', index=False)
