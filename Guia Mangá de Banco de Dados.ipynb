# %% [markdown]
# # **Guia Mangá de *Banco de Dados***

# %% [markdown]
# **Execícios Cápitulo 02**:<p>
# **Q1**  Chave Estrangeira - FK - FOREIGN KEY
#
# **Q2** ISBN
#
# **Q3** SELEÇÃO
#
# **Q4** UNIÃO
#
# **Q5** JUNÇÃO (JOIN)

# %% [markdown]
# **Execícios Cápitulo 03**:<p>
# ![Captura de tela de 2025-06-18 16-16-18.png](<attachment:Captura de tela de 2025-06-18 16-16-18.png>)
#
# **Q5** SEGUNDA FORMA NORMAL<p>
# **Q6** TERCEIRA FORMA NORMAL <p>
#
# ![Captura de tela de 2025-06-18 16-19-11.png](<attachment:Captura de tela de 2025-06-18 16-19-11.png>)

# %% [markdown]
# **Execícios Cápitulo 04**:<p>
#
# **Q1** SELECT *
#        FROM destinos_exportacao
#        WHERE populacao >= 100
#
# **Q2** SELECT *
#        FROM destinos_exportacao
#        WHERE populacao < 100
#
# **Q3** SELECT *
#        FROM destinos_exportacao
#        WHERE populacao >= 100
#        AND codigo_destino_exportacao < 20
#
# **Q4** SELECT *
#        FROM destinos_exportacao
#        WHERE codigo_destino_exportacao >= 30
#        AND populacao > 100
#
# **Q5** SELECT *
#        FROM destinos_exportacao
#        WHERE nome_destino_exportacao = "Reino de Ritol"
#
# **Q6** SELECT *
#        FROM destinos_exportacao
#        WHERE nome_destino_exportacao Like "%N%"
#
# **Q1** SELECT *
#        FROM destinos_exportacao
#        WHERE populacao >= 100
#
# **Q2** SELECT *
#        FROM destinos_exportacao
#        WHERE populacao < 100
#
# **Q3** SELECT *
#        FROM destinos_exportacao
#        WHERE populacao >= 100
#        AND codigo_destino_exportacao < 20
#
# **Q4** SELECT *
#        FROM destinos_exportacao
#        WHERE codigo_destino_exportacao >= 30
#        AND populacao > 100
#
# **Q5** SELECT *
#        FROM destinos_exportacao
#        WHERE nome_destino_exportacao = "Reino de Ritol"
#
# **Q6** SELECT *
#        FROM destinos_exportacao
#        WHERE nome_destino_exportacao Like "%N%"
#
# **Q7** SELECT MIN(Populacao)
#        FROM destinos_exportacao
#
# **Q8** SELECT MAX(Populacao)
#        FROM destinos_exportacao
#
# **Q9** SELECT SUM(Populacao)
#        FROM destinos_exportacao
#
# **Q10** SELECT SUM(Populacao)
#        FROM destinos_exportacao
#        WHERE codigo_destino_exportacao > 20
#
# **Q11** SELECT COUNT(*)
#        FROM destinos_exportacao
#        WHERE codigo_destino_exportacao >= 100
#
# **Q12** SELECT COUNT(*)
#        FROM destinos_exportacao
#        WHERE distrito = "Mar do Norte"
#
# **Q13** SELECT MAX(Populacao)
#        FROM destinos_exportacao
#        WHERE distrito = "Mar do Norte"
#
# **Q14** SELECT SUM(Populacao)
#        FROM destinos_exportacao
#        WHERE NOT (nome_destino_exportacao = "Reino de Ritol")
#
# **Q15** SELECT AVG(Populacao), Distrito
#        FROM destinos_exportacao
#        GROUP BY distrito
#        WHERE AVG(Populacao) >= 200
#
# **Q16** SELECT Distrito, COUNT(*)
#        FROM destinos_exportacao
#        GROUP BY distrito
#        WHERE COUNT(*) >= 3
#
# **Q17** SELECT *
#         FROM detalhes_vendas
#         WHERE codigo_produto IN (
#             SELECT codigo_produto
#             FROM produto
#             WHERE preco_unitario >= 300
#         )
#
# **Q18** SELECT *
#        FROM detalhes_vendas U
#        WHERE quantidades < (
#         SELECT AVG(quantidade)
#         FROM detalhes_vendas
#         WHERE codigo_produto = U.codigo_produto
#        )
